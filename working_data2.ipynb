# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
players = pd.read_csv('data2/Players.csv')
players.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
s_stats = pd.read_csv('data2/Seasons_Stats.csv')
s_stats.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#      TS%  3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  blanl  \
# 0  0.368   NaN  0.467   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 1  0.435   NaN  0.387   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2  0.394   NaN  0.259   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 3  0.312   NaN  0.395   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 4  0.308   NaN  0.378   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
# ...

# %%
p_data = pd.read_csv('data2/player_data.csv')
p_data.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %% [markdown]
# ## Data Exploration

# %%
s_stats.shape
# Out:
# (24691, 53)

# %%
s_stats['Player']
# Out:
# 0          Curly Armstrong
# 1             Cliff Barker
# 2            Leo Barnhorst
# 3               Ed Bartels
# 4               Ed Bartels
#                ...
# 24686          Cody Zeller
# 24687         Tyler Zeller
# 24688    Stephen Zimmerman
# 24689          Paul Zipser
# 24690          Ivica Zubac
# Name: Player, Length: 24691, dtype: object

# %%
s_stats['GS'].notna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 24686     True
# 24687     True
# 24688     True
# 24689     True
# 24690     True
# Name: GS, Length: 24691, dtype: bool

# %%
main_stats = s_stats[s_stats['Year'] > 1999]
main_stats.head()
# Out:
#        Unnamed: 0    Year               Player Pos   Age   Tm     G    GS  \
# 14470       14470  2000.0    Tariq Abdul-Wahad  SG  25.0  TOT  61.0  56.0
# 14471       14471  2000.0    Tariq Abdul-Wahad  SG  25.0  ORL  46.0  46.0
# 14472       14472  2000.0    Tariq Abdul-Wahad  SG  25.0  DEN  15.0  10.0
# 14473       14473  2000.0  Shareef Abdur-Rahim  SF  23.0  VAN  82.0  82.0
# 14474       14474  2000.0       Cory Alexander  PG  26.0  DEN  29.0   2.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# 14470  1578.0  13.6  0.477  0.036  0.299   7.0  13.1  10.0  10.0   1.8   1.2
# 14471  1205.0  14.4  0.484  0.041  0.293   7.0  14.6  10.8   9.7   2.2   0.9
# 14472   373.0  10.8  0.448  0.015  0.321   6.9   8.2   7.6  11.0   0.8   2.2
# 14473  3223.0  20.2  0.547  0.075  0.431   8.0  22.7  15.3  15.5   1.5   1.9
# 14474   329.0   8.8  0.381  0.357  0.224   2.6  11.3   6.9  25.7   3.7   0.4
#
# ...

# %%
main_stats['ppg'] = main_stats['PTS']/main_stats['G']
main_stats.head()
# Out:
# <ipython-input-10-d4cb86a7a4c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_stats['ppg'] = main_stats['PTS']/main_stats['G']
#        Unnamed: 0    Year               Player Pos   Age   Tm     G    GS  \
# 14470       14470  2000.0    Tariq Abdul-Wahad  SG  25.0  TOT  61.0  56.0
# 14471       14471  2000.0    Tariq Abdul-Wahad  SG  25.0  ORL  46.0  46.0
# 14472       14472  2000.0    Tariq Abdul-Wahad  SG  25.0  DEN  15.0  10.0
# 14473       14473  2000.0  Shareef Abdur-Rahim  SF  23.0  VAN  82.0  82.0
# 14474       14474  2000.0       Cory Alexander  PG  26.0  DEN  29.0   2.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %%
main_stats['rpg'] = main_stats['TRB']/main_stats['G']
main_stats.head()
# Out:
# <ipython-input-11-9ade0da1ffd9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_stats['rpg'] = main_stats['TRB']/main_stats['G']
#        Unnamed: 0    Year               Player Pos   Age   Tm     G    GS  \
# 14470       14470  2000.0    Tariq Abdul-Wahad  SG  25.0  TOT  61.0  56.0
# 14471       14471  2000.0    Tariq Abdul-Wahad  SG  25.0  ORL  46.0  46.0
# 14472       14472  2000.0    Tariq Abdul-Wahad  SG  25.0  DEN  15.0  10.0
# 14473       14473  2000.0  Shareef Abdur-Rahim  SF  23.0  VAN  82.0  82.0
# 14474       14474  2000.0       Cory Alexander  PG  26.0  DEN  29.0   2.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %%
main_stats['apg'] = main_stats['AST']/main_stats['G']
main_stats.head()
# Out:
# <ipython-input-12-3f5e0e60ca2a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_stats['apg'] = main_stats['AST']/main_stats['G']
#        Unnamed: 0    Year               Player Pos   Age   Tm     G    GS  \
# 14470       14470  2000.0    Tariq Abdul-Wahad  SG  25.0  TOT  61.0  56.0
# 14471       14471  2000.0    Tariq Abdul-Wahad  SG  25.0  ORL  46.0  46.0
# 14472       14472  2000.0    Tariq Abdul-Wahad  SG  25.0  DEN  15.0  10.0
# 14473       14473  2000.0  Shareef Abdur-Rahim  SF  23.0  VAN  82.0  82.0
# 14474       14474  2000.0       Cory Alexander  PG  26.0  DEN  29.0   2.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %%
main_stats['spg'] = main_stats['STL']/main_stats['G']
main_stats.head()
# Out:
# <ipython-input-13-aa82b02c3723>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_stats['spg'] = main_stats['STL']/main_stats['G']
#        Unnamed: 0    Year               Player Pos   Age   Tm     G    GS  \
# 14470       14470  2000.0    Tariq Abdul-Wahad  SG  25.0  TOT  61.0  56.0
# 14471       14471  2000.0    Tariq Abdul-Wahad  SG  25.0  ORL  46.0  46.0
# 14472       14472  2000.0    Tariq Abdul-Wahad  SG  25.0  DEN  15.0  10.0
# 14473       14473  2000.0  Shareef Abdur-Rahim  SF  23.0  VAN  82.0  82.0
# 14474       14474  2000.0       Cory Alexander  PG  26.0  DEN  29.0   2.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %%
main_stats['bpg'] = main_stats['BLK']/main_stats['G']
main_stats.head()
# Out:
# <ipython-input-14-edc29a8f2c71>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   main_stats['bpg'] = main_stats['BLK']/main_stats['G']
#        Unnamed: 0    Year               Player Pos   Age   Tm     G    GS  \
# 14470       14470  2000.0    Tariq Abdul-Wahad  SG  25.0  TOT  61.0  56.0
# 14471       14471  2000.0    Tariq Abdul-Wahad  SG  25.0  ORL  46.0  46.0
# 14472       14472  2000.0    Tariq Abdul-Wahad  SG  25.0  DEN  15.0  10.0
# 14473       14473  2000.0  Shareef Abdur-Rahim  SF  23.0  VAN  82.0  82.0
# 14474       14474  2000.0       Cory Alexander  PG  26.0  DEN  29.0   2.0
#
#            MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  \
# ...

# %%
main_stats['blanl'].value_counts()
# Out:
# Series([], Name: blanl, dtype: int64)
