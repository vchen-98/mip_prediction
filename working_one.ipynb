# %%
import pandas as pd
import numpy as np

import sqlite3

# To see datasets within this file:
# https://www.kaggle.com/wyattowalsh/basketball

# How to access sqlite3 in jupyter notebook:
# https://andrewpuleo.com/sqlite-and-jupyter/

# %% [markdown]
# ### Example Walkthrough of Accessing sqlite

# %%
conn = sqlite3.connect('data/basketball.sqlite')

# %%
cur = conn.cursor()

# %%
cur.execute('SELECT * FROM Player LIMIT 5')

# %%
results = cur.fetchall()
print(results)
# Out:
# [('76001', 'Alaa Abdelnaby', 'Alaa', 'Abdelnaby', 0), ('76002', 'Zaid Abdul-Aziz', 'Zaid', 'Abdul-Aziz', 0), ('76003', 'Kareem Abdul-Jabbar', 'Kareem', 'Abdul-Jabbar', 0), ('51', 'Mahmoud Abdul-Rauf', 'Mahmoud', 'Abdul-Rauf', 0), ('1505', 'Tariq Abdul-Wahad', 'Tariq', 'Abdul-Wahad', 0)]

# %%
players = pd.read_sql_query('SELECT * FROM Player', conn)
players.head()
# Out:
#       id            full_name first_name     last_name  is_active
# 0  76001       Alaa Abdelnaby       Alaa     Abdelnaby          0
# 1  76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz          0
# 2  76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar          0
# 3     51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf          0
# 4   1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad          0

# %%
players.shape
# Out:
# (4501, 5)

# %%
cur.close()
conn.close()

# %% [markdown]
# ### Project Coding Begins Here

# %%
conn = sqlite3.connect('data/basketball.sqlite')

# %%
# assigning players to the 'players' variable as dataframe
players = pd.read_sql_query('SELECT * FROM Player', conn)
players.head()
# Out:
#       id            full_name first_name     last_name  is_active
# 0  76001       Alaa Abdelnaby       Alaa     Abdelnaby          0
# 1  76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz          0
# 2  76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar          0
# 3     51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf          0
# 4   1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad          0

# %%
pd.set_option('display.max_columns', None)

# %%
# assigning players to the 'players' variable as dataframe
play_atts = pd.read_sql_query('SELECT * FROM Player_Attributes', conn)
play_atts.head()
# Out:
#       ID FIRST_NAME     LAST_NAME   DISPLAY_FIRST_LAST  \
# 0  76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1  76002       Zaid    Abdul-Aziz      Zaid Abdul-Aziz
# 2  76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 3     51    Mahmoud    Abdul-Rauf   Mahmoud Abdul-Rauf
# 4   1505      Tariq   Abdul-Wahad    Tariq Abdul-Wahad
#
#   DISPLAY_LAST_COMMA_FIRST  DISPLAY_FI_LAST          PLAYER_SLUG  \
# 0          Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1         Abdul-Aziz, Zaid    Z. Abdul-Aziz      zaid-abdul-aziz
# 2     Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# 3      Abdul-Rauf, Mahmoud    M. Abdul-Rauf   mahmoud-abdul-rauf
# 4       Abdul-Wahad, Tariq   T. Abdul-Wahad    tariq-abdul-wahad
#
#              BIRTHDATE           SCHOOL COUNTRY       LAST_AFFILIATION  \
# 0  1968-06-24T00:00:00             Duke     USA               Duke/USA
# 1  1946-04-07T00:00:00       Iowa State     USA         Iowa State/USA
# ...
